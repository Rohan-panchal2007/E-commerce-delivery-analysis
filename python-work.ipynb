# %%
import pandas as pd

# %%
df=pd.read_csv("ecommerce_delivery_report.csv")

# %%
df.head()
# Out:
#     Order ID Customer ID Platform  Delivery Time (Minutes)  \
# 0  ORD000001    CUST2824  JioMart                       30
# 1  ORD000002    CUST1409  Blinkit                       16
# 2  ORD000003    CUST5506  JioMart                       25
# 3  ORD000004    CUST5012  JioMart                       42
# 4  ORD000005    CUST4657  Blinkit                       30
#
#       Product Category  Order Value (INR)              Customer Feedback  \
# 0  Fruits & Vegetables                382  Fast delivery, great service!
# 1                Dairy                279            Quick and reliable!
# 2            Beverages                599      Items missing from order.
# 3            Beverages                946      Items missing from order.
# 4            Beverages                334  Fast delivery, great service!
#
#    Service Rating Delivery Delay Refund Requested
# 0               5             No               No
# 1               5             No               No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Order ID                 100000 non-null  object
#  1   Customer ID              100000 non-null  object
#  2   Platform                 100000 non-null  object
#  3   Delivery Time (Minutes)  100000 non-null  int64
#  4   Product Category         100000 non-null  object
#  5   Order Value (INR)        100000 non-null  int64
#  6   Customer Feedback        100000 non-null  object
#  7   Service Rating           100000 non-null  int64
#  8   Delivery Delay           100000 non-null  object
#  9   Refund Requested         100000 non-null  object
# dtypes: int64(3), object(7)
# memory usage: 7.6+ MB

# %%
df.describe(include="all")
# Out:
#          Order ID Customer ID          Platform  Delivery Time (Minutes)  \
# count      100000      100000            100000            100000.000000
# unique     100000        9000                 3                      NaN
# top     ORD000001    CUST8779  Swiggy Instamart                      NaN
# freq            1          26             33449                      NaN
# mean          NaN         NaN               NaN                29.536140
# std           NaN         NaN               NaN                 9.958933
# min           NaN         NaN               NaN                 5.000000
# 25%           NaN         NaN               NaN                23.000000
# 50%           NaN         NaN               NaN                30.000000
# 75%           NaN         NaN               NaN                36.000000
# max           NaN         NaN               NaN                76.000000
#
#        Product Category  Order Value (INR)         Customer Feedback  \
# ...

# %%
df.isnull().sum()
# Out:
# Order ID                   0
# Customer ID                0
# Platform                   0
# Delivery Time (Minutes)    0
# Product Category           0
# Order Value (INR)          0
# Customer Feedback          0
# Service Rating             0
# Delivery Delay             0
# Refund Requested           0
# dtype: int64

# %%
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(' ','_')
df=df.rename(columns={'delivery_time_(minutes)':'delivery_time' ,'order_value_(inr)':'order_value'})

# %%
df.columns
# Out:
# Index(['order_id', 'customer_id', 'platform', 'delivery_time',
#        'product_category', 'order_value', 'customer_feedback',
#        'service_rating', 'delivery_delay', 'refund_requested'],
#       dtype='object')

# %%
#column name cleaned
#there is no null value

# %%
#exporting data to mysql

from sqlalchemy import create_engine
from urllib.parse import quote_plus

password = quote_plus("rohan123@")

engine = create_engine(
    f"mysql+pymysql://root:{password}@localhost:3306/ecommerce_delivery"
)

df.to_sql("ecommerce", engine, if_exists="replace", index=False)


pd.read_sql("SELECT * FROM ecommerce LIMIT 5;", engine)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
# ...

# %%
pd.read_sql("SELECT * FROM ecommerce LIMIT 5;", engine)
# Out:
#     order_id customer_id platform  delivery_time     product_category  \
# 0  ORD000001    CUST2824  JioMart             30  Fruits & Vegetables
# 1  ORD000002    CUST1409  Blinkit             16                Dairy
# 2  ORD000003    CUST5506  JioMart             25            Beverages
# 3  ORD000004    CUST5012  JioMart             42            Beverages
# 4  ORD000005    CUST4657  Blinkit             30            Beverages
#
#    order_value              customer_feedback  service_rating delivery_delay  \
# 0          382  Fast delivery, great service!               5             No
# 1          279            Quick and reliable!               5             No
# 2          599      Items missing from order.               2             No
# 3          946      Items missing from order.               2            Yes
# 4          334  Fast delivery, great service!               5             No
#
#   refund_requested
# 0               No
# 1               No
# 2              Yes
# ...
